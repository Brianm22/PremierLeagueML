# %% [markdown]
# # Adding imports

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics 
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %% [markdown]
# # Adding adverage goals scoredand conceded for home and away team

# %%
allPremDataDF = pd.read_csv("csv/AllDataNoGoalsAtHalfTime.csv")
allPremDataDF[['homeGoalsScored', 'homeGolsConceded']] = allPremDataDF.homeGoals.str.split(":", expand = True,)
allPremDataDF[['awayGoalsScored', 'awayGolsConceded']] = allPremDataDF.awayGoals.str.split(":", expand = True,)
# allPremDataDF
cleanedallPremDataDF = allPremDataDF.drop(['homeGoals'], axis=1).drop(['awayGoals'], axis=1).drop(['homeGoalDif'], axis=1).drop(['awayGoalDif'], axis=1)
cleanedallPremDataDF
# Out:
#      homePosition  homePlayed  homeWon  homeDraw  homeLost  homePoints  \
# 0              12          22        7         6         9          27
# 1              18          32        7         7        18          28
# 2              13          26        8         6        12          30
# 3              17          29        7         8        14          29
# 4               7          18        8         6         4          30
# ...           ...         ...      ...       ...       ...         ...
# 5795            2          25       17         4         4          55
# 5796            2          32       21         7         4          70
# 5797           10          25        6        13         6          31
# 5798            2          14        9         4         1          31
# 5799            1          21       12         6         3          42
#
#       awayPosition  awayPlayed  awayWon  awayDraw  awayLost  awayPoints  \
# 0             16.0          22        4        10         8          22
# 1              6.0          32       16         5        11          53
# 2             11.0          26        8         8        10          32
# 3              6.0          29       13         9         7          48
# 4              1.0          18       13         4         1          43
# ...            ...         ...      ...       ...       ...         ...
# 5795           7.0          25       12         5         8          41
# 5796           4.0          32       16         6        10          54
# 5797          12.0          25        8         7        10          31
# 5798           9.0          14        5         4         5          19
# 5799           5.0          21       11         5         5          38
#
#       score homeGoalsScored homeGolsConceded awayGoalsScored awayGolsConceded
# 0         0              26               30              20               33
# 1         0              28               53              43               37
# 2         0              29               38              29               33
# 3         0              30               47              39               29
# 4         1              29               19              36               15
# ...     ...             ...              ...             ...              ...
# 5795      1              48               26              41               31
# 5796      0              73               33              39               33
# 5797      0              32               34              24               36
# 5798      0              33               14              16               19
# 5799      0              44               25              30               22
#
# [5800 rows x 17 columns]

# %% [markdown]
# # Setting the average goals scored and conceded for home and away team

# %%
cleanedallPremDataDF['homeGoalsScored'] = pd.to_numeric(cleanedallPremDataDF['homeGoalsScored']) / pd.to_numeric(cleanedallPremDataDF['homePlayed'])
cleanedallPremDataDF['homeGolsConceded'] = pd.to_numeric(cleanedallPremDataDF['homeGolsConceded']) / pd.to_numeric(cleanedallPremDataDF['homePlayed'])
cleanedallPremDataDF['awayGoalsScored'] = pd.to_numeric(cleanedallPremDataDF['awayGoalsScored']) / pd.to_numeric(cleanedallPremDataDF['awayPlayed'])
cleanedallPremDataDF['awayGolsConceded'] = pd.to_numeric(cleanedallPremDataDF['awayGolsConceded']) / pd.to_numeric(cleanedallPremDataDF['awayPlayed'])

# %% [markdown]
# # Getting averages per game

# %%
cleanedallPremDataDF['homeWon'] = pd.to_numeric(cleanedallPremDataDF['homeWon']) / pd.to_numeric(cleanedallPremDataDF['homePlayed'])
cleanedallPremDataDF['homeDraw'] = pd.to_numeric(cleanedallPremDataDF['homeDraw']) / pd.to_numeric(cleanedallPremDataDF['homePlayed'])
cleanedallPremDataDF['homeLost'] = pd.to_numeric(cleanedallPremDataDF['homeLost']) / pd.to_numeric(cleanedallPremDataDF['homePlayed'])
cleanedallPremDataDF['homePoints'] = pd.to_numeric(cleanedallPremDataDF['homePoints']) / pd.to_numeric(cleanedallPremDataDF['homePlayed'])

cleanedallPremDataDF['awayWon'] = pd.to_numeric(cleanedallPremDataDF['awayWon']) / pd.to_numeric(cleanedallPremDataDF['awayPlayed'])
cleanedallPremDataDF['awayDraw'] = pd.to_numeric(cleanedallPremDataDF['awayDraw']) / pd.to_numeric(cleanedallPremDataDF['awayPlayed'])
cleanedallPremDataDF['awayLost'] = pd.to_numeric(cleanedallPremDataDF['awayLost']) / pd.to_numeric(cleanedallPremDataDF['awayPlayed'])
cleanedallPremDataDF['awayPoints'] = pd.to_numeric(cleanedallPremDataDF['awayPoints']) / pd.to_numeric(cleanedallPremDataDF['awayPlayed'])
cleanedallPremDataDF = cleanedallPremDataDF.drop(['homePlayed'], axis=1).drop(['awayPlayed'], axis=1)
cleanedallPremDataDF
# Out:
#      homePosition   homeWon  homeDraw  homeLost  homePoints  awayPosition  \
# 0              12  0.318182  0.272727  0.409091    1.227273          16.0
# 1              18  0.218750  0.218750  0.562500    0.875000           6.0
# 2              13  0.307692  0.230769  0.461538    1.153846          11.0
# 3              17  0.241379  0.275862  0.482759    1.000000           6.0
# 4               7  0.444444  0.333333  0.222222    1.666667           1.0
# ...           ...       ...       ...       ...         ...           ...
# 5795            2  0.680000  0.160000  0.160000    2.200000           7.0
# 5796            2  0.656250  0.218750  0.125000    2.187500           4.0
# 5797           10  0.240000  0.520000  0.240000    1.240000          12.0
# 5798            2  0.642857  0.285714  0.071429    2.214286           9.0
# 5799            1  0.571429  0.285714  0.142857    2.000000           5.0
#
#        awayWon  awayDraw  awayLost  awayPoints  score  homeGoalsScored  \
# 0     0.181818  0.454545  0.363636    1.000000      0         1.181818
# 1     0.500000  0.156250  0.343750    1.656250      0         0.875000
# 2     0.307692  0.307692  0.384615    1.230769      0         1.115385
# 3     0.448276  0.310345  0.241379    1.655172      0         1.034483
# 4     0.722222  0.222222  0.055556    2.388889      1         1.611111
# ...        ...       ...       ...         ...    ...              ...
# 5795  0.480000  0.200000  0.320000    1.640000      1         1.920000
# 5796  0.500000  0.187500  0.312500    1.687500      0         2.281250
# 5797  0.320000  0.280000  0.400000    1.240000      0         1.280000
# 5798  0.357143  0.285714  0.357143    1.357143      0         2.357143
# 5799  0.523810  0.238095  0.238095    1.809524      0         2.095238
#
#       homeGolsConceded  awayGoalsScored  awayGolsConceded
# 0             1.363636         0.909091          1.500000
# 1             1.656250         1.343750          1.156250
# 2             1.461538         1.115385          1.269231
# 3             1.620690         1.344828          1.000000
# 4             1.055556         2.000000          0.833333
# ...                ...              ...               ...
# 5795          1.040000         1.640000          1.240000
# 5796          1.031250         1.218750          1.031250
# 5797          1.360000         0.960000          1.440000
# 5798          1.000000         1.142857          1.357143
# 5799          1.190476         1.428571          1.047619
#
# [5800 rows x 15 columns]

# %% [markdown]
# # Getting only numeric values from the dataframe

# %%
cleanedallPremDataDF = cleanedallPremDataDF.apply (pd.to_numeric, errors='coerce')
cleanedallPremDataDF = cleanedallPremDataDF.dropna()
cleanedallPremDataDF
# Out:
#       homePosition   homeWon  homeDraw  homeLost  homePoints  awayPosition  \
# 0             12.0  0.318182  0.272727  0.409091    1.227273          16.0
# 1             18.0  0.218750  0.218750  0.562500    0.875000           6.0
# 2             13.0  0.307692  0.230769  0.461538    1.153846          11.0
# 3             17.0  0.241379  0.275862  0.482759    1.000000           6.0
# 4              7.0  0.444444  0.333333  0.222222    1.666667           1.0
# ...            ...       ...       ...       ...         ...           ...
# 5795           2.0  0.680000  0.160000  0.160000    2.200000           7.0
# 5796           2.0  0.656250  0.218750  0.125000    2.187500           4.0
# 5797          10.0  0.240000  0.520000  0.240000    1.240000          12.0
# 5798           2.0  0.642857  0.285714  0.071429    2.214286           9.0
# 5799           1.0  0.571429  0.285714  0.142857    2.000000           5.0
#
#        awayWon  awayDraw  awayLost  awayPoints  score  homeGoalsScored  \
# 0     0.181818  0.454545  0.363636    1.000000      0         1.181818
# 1     0.500000  0.156250  0.343750    1.656250      0         0.875000
# 2     0.307692  0.307692  0.384615    1.230769      0         1.115385
# 3     0.448276  0.310345  0.241379    1.655172      0         1.034483
# 4     0.722222  0.222222  0.055556    2.388889      1         1.611111
# ...        ...       ...       ...         ...    ...              ...
# 5795  0.480000  0.200000  0.320000    1.640000      1         1.920000
# 5796  0.500000  0.187500  0.312500    1.687500      0         2.281250
# 5797  0.320000  0.280000  0.400000    1.240000      0         1.280000
# 5798  0.357143  0.285714  0.357143    1.357143      0         2.357143
# 5799  0.523810  0.238095  0.238095    1.809524      0         2.095238
#
#       homeGolsConceded  awayGoalsScored  awayGolsConceded
# 0             1.363636         0.909091          1.500000
# 1             1.656250         1.343750          1.156250
# 2             1.461538         1.115385          1.269231
# 3             1.620690         1.344828          1.000000
# 4             1.055556         2.000000          0.833333
# ...                ...              ...               ...
# 5795          1.040000         1.640000          1.240000
# 5796          1.031250         1.218750          1.031250
# 5797          1.360000         0.960000          1.440000
# 5798          1.000000         1.142857          1.357143
# 5799          1.190476         1.428571          1.047619
#
# [5787 rows x 15 columns]

# %% [markdown]
# # Setting up score to be the result field and using 25% of the data for testing

# %%
#x = cleanedallPremDataDF.drop('score', axis=1)
#x = cleanedallPremDataDF[['homePosition','awayPosition']]
x = cleanedallPremDataDF[['homeGoalsScored','homeGolsConceded', 'awayGoalsScored', 'awayGolsConceded', 'homePosition', 'awayPosition']]
y = cleanedallPremDataDF['score']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)
print("{0:0.2f}% in training set".format((len(x_train)/len(cleanedallPremDataDF.index)) * 100))
print("{0:0.2f}% in test set".format((len(x_test)/len(cleanedallPremDataDF.index)) * 100))
# Out:
# 75.00% in training set
# 25.00% in test set

# %%
print("Original Over : {0} ({1:0.2f}%)".format(len(cleanedallPremDataDF.loc[cleanedallPremDataDF['score'] == 1]), (len(cleanedallPremDataDF.loc[cleanedallPremDataDF['score'] == 1])/len(cleanedallPremDataDF.index)) * 100))
print("Original Under : {0} ({1:0.2f}%)".format(len(cleanedallPremDataDF.loc[cleanedallPremDataDF['score'] == 0]), (len(cleanedallPremDataDF.loc[cleanedallPremDataDF['score'] == 0])/len(cleanedallPremDataDF.index)) * 100))
print("")
print("Training Over : {0} ({1:0.2f}%)".format(len(y_train[y_train[:] == 1]), (len(y_train[y_train[:] == 1])/len(y_train)) * 100))
print("Trianing Under : {0} ({1:0.2f}%)".format(len(y_train[y_train[:] == 0]), (len(y_train[y_train[:] == 0])/len(y_train)) * 100))
print("")
print("Test Over : {0} ({1:0.2f}%)".format(len(y_test[y_test[:] == 1]), (len(y_test[y_test[:] == 1])/len(y_test)) * 100))
print("Test Under : {0} ({1:0.2f}%)".format(len(y_test[y_test[:] == 0]), (len(y_test[y_test[:] == 0])/len(y_test)) * 100))
print("")
# Out:
# Original Over : 445 (7.69%)
# Original Under : 5342 (92.31%)
#
# Training Over : 335 (7.72%)
# Trianing Under : 4005 (92.28%)
#
# Test Over : 110 (7.60%)
# Test Under : 1337 (92.40%)

# %% [markdown]
# # Testing Accuracy

# %%
model = GaussianNB()
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_train = model.predict(x_train)
#newData = pd.read_csv("csv\league_table.csv", delimiter='\t')

# newData['W'] = pd.to_numeric(newData['W']) / pd.to_numeric(cleanedallPremDataDF['M.'])
# newData['D'] = pd.to_numeric(newData['D']) / pd.to_numeric(cleanedallPremDataDF['M.'])
# newData['L'] = pd.to_numeric(newData['L']) / pd.to_numeric(cleanedallPremDataDF['M.'])
# newData[['GoalsScored', 'GolsConceded']] = newData.goals.str.split(":", expand = True)
# newData['GoalsScored'] = pd.to_numeric(newData['GoalsScored']) / pd.to_numeric(newData["M."])
# newData['GolsConceded'] = pd.to_numeric(newData['GolsConceded']) / pd.to_numeric(newData["M."])
# newData
#'homeGoalsScored','homeGolsConceded', 'awayGoalsScored', 'awayGolsConceded', 'homePosition', 'awayPosition'
# homeTeam = 10
# awayTeam = 18
# tmp=newData.loc[[homeTeam, awayTeam]]

# %%
#nuumpy.array([home[]])
#tmp=tmp[["GoalsScored", "GolsConceded", "Pos"]]
#home = tmp.loc[homeTeam]
#away = tmp.loc[awayTeam]
#testing = pd.DataFrame(np.array([home[0],home[1],away[0],away[1],home[2],away[2]])

# %% [markdown]
# # Getting the accuracy of the prediction

# %%
accuracy = accuracy_score(y_train, y_pred_train)*100
accuracy
# Out:
# 92.2811059907834

# %%
y_pred_test = model.predict(x_test)
accuracy_test = accuracy_score(y_test, y_pred_test)*100
accuracy_test
# Out:
# 92.39806496199033

# %% [markdown]
# Metrics

# %%
print("Confusion Matrix")
print("{0}".format(metrics.confusion_matrix(y_test, y_pred_test)))
print("")

print("Classsisfication Report")
print(metrics.classification_report(y_test, y_pred_test))
# Out:
# Confusion Matrix
# [[1337    0]
#  [ 110    0]]
#
# Classsisfication Report
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      1337
#            1       0.00      0.00      0.00       110
#
#     accuracy                           0.92      1447
#    macro avg       0.46      0.50      0.48      1447
# weighted avg       0.85      0.92      0.89      1447
# C:\Users\bmuis\Miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Ransom Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(x_train, y_train.ravel())
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_predict_train =rf_model.predict(x_train)
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_train, rf_predict_train)))
# Out:
# Accuracy: 1.0000

# %%
rf_predict_test = rf_model.predict(x_test)
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(y_test, rf_predict_test)))
# Out:
# Accuracy: 0.9240

# %%
print("Confusion Matrix")
print("{0}".format(metrics.confusion_matrix(y_test, rf_predict_test), zero_division=1))
print("")

print("Classsisfication Report")
print(metrics.classification_report(y_test, rf_predict_test, zero_division=1))
# Out:
# Confusion Matrix
# [[1337    0]
#  [ 110    0]]
#
# Classsisfication Report
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      1337
#            1       1.00      0.00      0.00       110
#
#     accuracy                           0.92      1447
#    macro avg       0.96      0.50      0.48      1447
# weighted avg       0.93      0.92      0.89      1447

# %% [markdown]
# # Logistics Regression

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(C=0.7, random_state=42, max_iter=1000)
lr_model.fit(x_train, y_train.ravel())
lr_predict_test = lr_model.predict(x_test)

#training metric
print("Accuracy: {0:4f}".format(metrics.accuracy_score(y_test, lr_predict_test)))
print(metrics.confusion_matrix(y_test, lr_predict_test))
print("")
print("Classification Report")
print(metrics.classification_report(y_test, lr_predict_test))
# Out:
# Accuracy: 0.923981
# [[1337    0]
#  [ 110    0]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      1337
#            1       0.00      0.00      0.00       110
#
#     accuracy                           0.92      1447
#    macro avg       0.46      0.50      0.48      1447
# weighted avg       0.85      0.92      0.89      1447
# C:\Users\bmuis\Miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
